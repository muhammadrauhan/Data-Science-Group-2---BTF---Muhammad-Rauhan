# %% [markdown]
# # Task 14: Data Cleaning and Preprocessing with Pandas:

# %% [markdown]
# A comprehensive understanding of data cleaning and preprocessing techniques using Pandas.

# %% [markdown]
# ### Data: Flight Dataset

# %% [markdown]
# ##### About Dataset:

# %% [markdown]
# The dataset provides a comprehensive overview of flight details, focusing on various key attributes related to airline operations. It includes information on:
#
# - Airlines: Names of the airlines operating the flights.
# - Source and Destination: Cities where flights originate and land.
# - Total Stops: Number of stops made by the flights.
# - Price: Ticket prices for the respective flights.
# - Date, Month, and Year: Specific dates on which the flights are scheduled.
# - Departure and Arrival Times: Detailed hours and minutes for both departure and arrival.
# - Duration: Total duration of flights in hours and minutes.

# %% [markdown]
# ### Importing Libraries:

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %% [markdown]
# ### Loading a DataFrame:

# %%
data = pd.read_csv("flight_dataset.csv")
data
# Out:
#            Airline    Source Destination  Total_Stops  Price  Date  Month  \
# 0           IndiGo  Banglore   New Delhi            0   3897    24      3
# 1        Air India   Kolkata    Banglore            2   7662     1      5
# 2      Jet Airways     Delhi      Cochin            2  13882     9      6
# 3           IndiGo   Kolkata    Banglore            1   6218    12      5
# 4           IndiGo  Banglore   New Delhi            1  13302     1      3
# ...            ...       ...         ...          ...    ...   ...    ...
# 10678     Air Asia   Kolkata    Banglore            0   4107     9      4
# 10679    Air India   Kolkata    Banglore            0   4145    27      4
# 10680  Jet Airways  Banglore       Delhi            0   7229    27      4
# 10681      Vistara  Banglore   New Delhi            0  12648     1      3
# 10682    Air India     Delhi      Cochin            2  11753     9      5
#
#        Year  Dep_hours  Dep_min  Arrival_hours  Arrival_min  Duration_hours  \
# ...

# %% [markdown]
# ### Data Cleaning:

# %% [markdown]
# ##### Summary Statistics:

# %%
data.describe()
# Out:
#         Total_Stops         Price          Date         Month     Year  \
# count  10683.000000  10683.000000  10683.000000  10683.000000  10683.0
# mean       0.824207   9087.064121     13.508378      4.708602   2019.0
# std        0.675199   4611.359167      8.479277      1.164357      0.0
# min        0.000000   1759.000000      1.000000      3.000000   2019.0
# 25%        0.000000   5277.000000      6.000000      3.000000   2019.0
# 50%        1.000000   8372.000000     12.000000      5.000000   2019.0
# 75%        1.000000  12373.000000     21.000000      6.000000   2019.0
# max        4.000000  79512.000000     27.000000      6.000000   2019.0
#
#           Dep_hours       Dep_min  Arrival_hours   Arrival_min  \
# count  10683.000000  10683.000000   10683.000000  10683.000000
# mean      12.490686     24.411214      13.348778     24.690630
# std        5.748650     18.767980       6.859125     16.506036
# min        0.000000      0.000000       0.000000      0.000000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Airline         10683 non-null  object
#  1   Source          10683 non-null  object
#  2   Destination     10683 non-null  object
#  3   Total_Stops     10683 non-null  int64
#  4   Price           10683 non-null  int64
#  5   Date            10683 non-null  int64
#  6   Month           10683 non-null  int64
#  7   Year            10683 non-null  int64
#  8   Dep_hours       10683 non-null  int64
#  9   Dep_min         10683 non-null  int64
#  10  Arrival_hours   10683 non-null  int64
#  11  Arrival_min     10683 non-null  int64
#  12  Duration_hours  10683 non-null  int64
#  13  Duration_min    10683 non-null  int64
# dtypes: int64(11), object(3)
# memory usage: 1.0+ MB

# %% [markdown]
# ##### Checking for Missing Values:

# %%
print(data.isna().sum())
# Out:
# Airline           0
# Source            0
# Destination       0
# Total_Stops       0
# Price             0
# Date              0
# Month             0
# Year              0
# Dep_hours         0
# Dep_min           0
# Arrival_hours     0
# Arrival_min       0
# Duration_hours    0
# Duration_min      0
# dtype: int64

# %% [markdown]
# ##### Identify duplicate rows:

# %%
print(data.duplicated().sum())
# Out:
# 222

# %% [markdown]
# ##### Dropping duplicated rows:

# %%
data.drop_duplicates(inplace = True)

# %% [markdown]
# ##### Check rows and columns:

# %%
print(data.shape) # updated
# Out:
# (10461, 14)

# %% [markdown]
# ### Checking Outliers:

# %% [markdown]
# An **'outlier'** is an observation that far away from other data points.

# %%
# for Price
plt.figure(figsize=(12,8))
sns.boxplot(data = data,
           y = "Price")
plt.show()

# %%
# for Duration hours
plt.figure(figsize=(12,8))
sns.boxplot(data = data,
           y = "Duration_hours")
plt.show()

# %%
# for Total stops
plt.figure(figsize=(12,8))
sns.boxplot(data = data,
           y = "Total_Stops")
plt.show()

# %% [markdown]
# ##### Remove Outliers:

# %% [markdown]
# - Outliers were detected and removed using the Interquartile Range (IQR) method for numerical columns.

# %%
def rem_outliers(data, column):
    Q1 = data[column].quantile(0.25)
    Q3 = data[column].quantile(0.75)
    IQR = Q3 - Q1
    # upper threshold
    upper = Q3 + (1.5 * IQR)
    # lower threshold
    lower = Q1 - (1.5 * IQR)
    
    return data[(data[column] >= lower) & (data[column] <= upper)]

num_columns = ['Price', 'Dep_hours', 'Dep_min', 'Arrival_hours', 'Arrival_min',
               'Duration_hours', 'Duration_min', 'Total_Stops']
for column in num_columns:
    data = rem_outliers(data, column)

# %%
# For verification, after removing Outliers
plt.figure(figsize=(12,8))
sns.boxplot(data = data,
           y = "Price")
plt.show()

# %% [markdown]
# ### Datatypes:

# %%
print(data.dtypes)
# Out:
# Airline           object
# Source            object
# Destination       object
# Total_Stops        int64
# Price              int64
# Date               int64
# Month              int64
# Year               int64
# Dep_hours          int64
# Dep_min            int64
# Arrival_hours      int64
# Arrival_min        int64
# Duration_hours     int64
# Duration_min       int64
# dtype: object

# %% [markdown]
# # Another Data: Sample Flight Dataset

# %%
flight_data = {
    "Airline": ["Fly Jinnah", "Fly Dubai", "AirBlue", "Turkish Airline", "Fly Dubai"],
    "Source_City": ["Abu Dhabi", "Dubai", "Islamabad", "Istanbul", "Karachi"],
    "Destination_City": ["United Kingdom", "Saudia Arabia", "Oman", "Germany", "Dubai"],
    "Number_of_Stops": ["Non-stop", "1 Stop", "2 Stops", "Non-stop", "1 Stop"],
    "Ticket_Price": [550, 800, 1200, 650, 900],
    "Flight_Date": ["2024-08-01", "2024-08-05", "2024-08-10", "2024-08-15", "2024-08-20"],
    "Departure_Time": ["08:00 AM", "09:30 PM", "01:45 PM", "10:00 AM", "11:15 PM"],
    "Arrival_Time": ["10:00 PM", "06:45 AM", "05:30 AM", "02:00 PM", "03:15 AM"],
    "Flight_Duration": ["7h 30m", "13h 15m", "8h 45m", "15h 0m", "14h 30m"]
}

# %%
flight_df = pd.DataFrame(flight_data)
flight_df
# Out:
#            Airline Source_City Destination_City Number_of_Stops  Ticket_Price  \
# 0       Fly Jinnah   Abu Dhabi   United Kingdom        Non-stop           550
# 1        Fly Dubai       Dubai    Saudia Arabia          1 Stop           800
# 2          AirBlue   Islamabad             Oman         2 Stops          1200
# 3  Turkish Airline    Istanbul          Germany        Non-stop           650
# 4        Fly Dubai     Karachi            Dubai          1 Stop           900
#
#   Flight_Date Departure_Time Arrival_Time Flight_Duration
# 0  2024-08-01       08:00 AM     10:00 PM          7h 30m
# 1  2024-08-05       09:30 PM     06:45 AM         13h 15m
# 2  2024-08-10       01:45 PM     05:30 AM          8h 45m
# 3  2024-08-15       10:00 AM     02:00 PM          15h 0m
# 4  2024-08-20       11:15 PM     03:15 AM         14h 30m

# %% [markdown]
# ### Transform Values:

# %% [markdown]
# In Pandas, you can apply a function to transform values in a DataFrame using the apply() function. This allows you to modify data in a column or across multiple columns based on custom logic defined by a function.

# %%
# mapping for the Number_of_Stops transformation
stops_mapping = {
    "Non-stop": 0,
    "1 Stop": 1,
    "2 Stops": 2
}

# applying the transformation
flight_df['Number_of_Stops_Num'] = flight_df['Number_of_Stops'].map(stops_mapping)
flight_df
# Out:
#            Airline Source_City Destination_City Number_of_Stops  Ticket_Price  \
# 0       fly jinnah   abu dhabi   united kingdom        Non-stop           550
# 1         emirates       dubai    saudia arabia          1 Stop           800
# 2          airblue   islamabad             oman         2 Stops          1200
# 3  turkish airline    istanbul          germany        Non-stop           650
# 4         emirates     karachi            dubai          1 Stop           900
#
#   Flight_Date Departure_Time Arrival_Time Flight_Duration  \
# 0  2024-08-01       08:00 AM     10:00 PM          7h 30m
# 1  2024-08-05       09:30 PM     06:45 AM         13h 15m
# 2  2024-08-10       01:45 PM     05:30 AM          8h 45m
# 3  2024-08-15       10:00 AM     02:00 PM          15h 0m
# 4  2024-08-20       11:15 PM     03:15 AM         14h 30m
#
#    Number_of_Stops_Num  Price_Normalized  PriceZScore  FlightYear  \
# 0                    0          0.000000    -1.073578        2024
# ...

# %% [markdown]
# ## Normalization & Standardization:

# %% [markdown]
# Min-Max scaling and z-score normalization are two common techniques used to transform numerical data within a specific range or distribution.

# %% [markdown]
# ##### MIN-MAX Scaling:
#
# Min-Max scaling, also known as normalization, transforms the values of a numeric column to a common scale, typically between 0 and 1. It preserves the shape of the original distribution while compressing the range of values.

# %%
# Normalize the ticket price using Min-Max Scaling
flight_df['Price_Normalized'] = (flight_df['Ticket_Price'] - flight_df['Ticket_Price'].min()) / (flight_df['Ticket_Price'].max() - flight_df['Ticket_Price'].min())
    
flight_df.head()
# Out:
#            Airline Source_City Destination_City Number_of_Stops  Ticket_Price  \
# 0       Fly Jinnah   Abu Dhabi   United Kingdom        Non-stop           550
# 1        Fly Dubai       Dubai    Saudia Arabia          1 Stop           800
# 2          AirBlue   Islamabad             Oman         2 Stops          1200
# 3  Turkish Airline    Istanbul          Germany        Non-stop           650
# 4        Fly Dubai     Karachi            Dubai          1 Stop           900
#
#   Flight_Date Departure_Time Arrival_Time Flight_Duration  \
# 0  2024-08-01       08:00 AM     10:00 PM          7h 30m
# 1  2024-08-05       09:30 PM     06:45 AM         13h 15m
# 2  2024-08-10       01:45 PM     05:30 AM          8h 45m
# 3  2024-08-15       10:00 AM     02:00 PM          15h 0m
# 4  2024-08-20       11:15 PM     03:15 AM         14h 30m
#
#    Number_of_Stops_Num  Price_Normalized
# 0                    0          0.000000
# 1                    1          0.384615
# ...

# %% [markdown]
# ##### Z-Score Normalization (Standardization):
#
# Z-score normalization, or standardization, transforms the values of a numeric column to have a mean of 0 and a standard deviation of 1. It adjusts the values so that they are centered around 0 and scaled relative to the standard deviation.

# %%
# standardize a column( z - score normalization)
flight_df['PriceZScore'] = (flight_df['Ticket_Price'] - flight_df['Ticket_Price'].mean()) / flight_df['Ticket_Price'].std()

flight_df.head()
# Out:
#            Airline Source_City Destination_City Number_of_Stops  Ticket_Price  \
# 0       Fly Jinnah   Abu Dhabi   United Kingdom        Non-stop           550
# 1        Fly Dubai       Dubai    Saudia Arabia          1 Stop           800
# 2          AirBlue   Islamabad             Oman         2 Stops          1200
# 3  Turkish Airline    Istanbul          Germany        Non-stop           650
# 4        Fly Dubai     Karachi            Dubai          1 Stop           900
#
#   Flight_Date Departure_Time Arrival_Time Flight_Duration  \
# 0  2024-08-01       08:00 AM     10:00 PM          7h 30m
# 1  2024-08-05       09:30 PM     06:45 AM         13h 15m
# 2  2024-08-10       01:45 PM     05:30 AM          8h 45m
# 3  2024-08-15       10:00 AM     02:00 PM          15h 0m
# 4  2024-08-20       11:15 PM     03:15 AM         14h 30m
#
#    Number_of_Stops_Num  Price_Normalized  PriceZScore
# 0                    0          0.000000    -1.073578
# ...

# %% [markdown]
# ### Working with Strings:

# %% [markdown]
# ##### Convert columns of names, gender and disgnosis to lower case:
#
# - I have converted the three colunms using the funtion.

# %%
flight_df[['Airline', 'Source_City', 'Destination_City']] = flight_df[['Airline', 'Source_City', 'Destination_City']].apply(lambda x: x.str.lower())

flight_df.head()
# Out:
#            Airline Source_City Destination_City Number_of_Stops  Ticket_Price  \
# 0       fly jinnah   abu dhabi   united kingdom        Non-stop           550
# 1        fly dubai       dubai    saudia arabia          1 Stop           800
# 2          airblue   islamabad             oman         2 Stops          1200
# 3  turkish airline    istanbul          germany        Non-stop           650
# 4        fly dubai     karachi            dubai          1 Stop           900
#
#   Flight_Date Departure_Time Arrival_Time Flight_Duration  \
# 0  2024-08-01       08:00 AM     10:00 PM          7h 30m
# 1  2024-08-05       09:30 PM     06:45 AM         13h 15m
# 2  2024-08-10       01:45 PM     05:30 AM          8h 45m
# 3  2024-08-15       10:00 AM     02:00 PM          15h 0m
# 4  2024-08-20       11:15 PM     03:15 AM         14h 30m
#
#    Number_of_Stops_Num  Price_Normalized  PriceZScore
# 0                    0          0.000000    -1.073578
# ...

# %% [markdown]
# ##### Replace a specific substring in a column with another substring:

# %%
# just replace fly dubai with emirates

flight_df['Airline'] = flight_df['Airline'].str.replace('fly dubai', 'emirates')

print("\nDataFrame after replacing 'fly dubai' with 'emirates' in 'Airline' column:")
flight_df.head()
# Out:
# DataFrame after replacing 'fly dubai' with 'emirates' in 'Airline' column:
#            Airline Source_City Destination_City Number_of_Stops  Ticket_Price  \
# 0       fly jinnah   abu dhabi   united kingdom        Non-stop           550
# 1         emirates       dubai    saudia arabia          1 Stop           800
# 2          airblue   islamabad             oman         2 Stops          1200
# 3  turkish airline    istanbul          germany        Non-stop           650
# 4         emirates     karachi            dubai          1 Stop           900
#
#   Flight_Date Departure_Time Arrival_Time Flight_Duration  \
# 0  2024-08-01       08:00 AM     10:00 PM          7h 30m
# 1  2024-08-05       09:30 PM     06:45 AM         13h 15m
# 2  2024-08-10       01:45 PM     05:30 AM          8h 45m
# 3  2024-08-15       10:00 AM     02:00 PM          15h 0m
# 4  2024-08-20       11:15 PM     03:15 AM         14h 30m
#
#    Number_of_Stops_Num  Price_Normalized  PriceZScore
# ...

# %% [markdown]
# ### Working with Datetime:

# %% [markdown]
# ##### Extract year, month, and day from a date column:

# %%
df['FlightYear'] = pd.to_datetime(flight_df['Flight_Date']).dt.year
df['FlightMonth'] = pd.to_datetime(flight_df['Flight_Date']).dt.month
df['FlightDay'] = pd.to_datetime(flight_df['Flight_Date']).dt.day

print("\nDataFrame after extracting year, month, and day from 'Flight_Date':")
flight_df
# Out:
# DataFrame after extracting year, month, and day from 'Flight_Date':
#            Airline Source_City Destination_City Number_of_Stops  Ticket_Price  \
# 0       fly jinnah   abu dhabi   united kingdom        Non-stop           550
# 1         emirates       dubai    saudia arabia          1 Stop           800
# 2          airblue   islamabad             oman         2 Stops          1200
# 3  turkish airline    istanbul          germany        Non-stop           650
# 4         emirates     karachi            dubai          1 Stop           900
#
#   Flight_Date Departure_Time Arrival_Time Flight_Duration  \
# 0  2024-08-01       08:00 AM     10:00 PM          7h 30m
# 1  2024-08-05       09:30 PM     06:45 AM         13h 15m
# 2  2024-08-10       01:45 PM     05:30 AM          8h 45m
# 3  2024-08-15       10:00 AM     02:00 PM          15h 0m
# 4  2024-08-20       11:15 PM     03:15 AM         14h 30m
#
#    Number_of_Stops_Num  Price_Normalized  PriceZScore  FlightYear  \
# ...

# %% [markdown]
# ##### Filter rows based on a date range:

# %%
filter_dates = flight_df[(flight_df['Flight_Date'] >= '2024-08-01') & (flight_df['Flight_Date'] <= '2024-08-10')]
filter_dates
# Out:
#       Airline Source_City Destination_City Number_of_Stops  Ticket_Price  \
# 0  fly jinnah   abu dhabi   united kingdom        Non-stop           550
# 1    emirates       dubai    saudia arabia          1 Stop           800
# 2     airblue   islamabad             oman         2 Stops          1200
#
#   Flight_Date Departure_Time Arrival_Time Flight_Duration  \
# 0  2024-08-01       08:00 AM     10:00 PM          7h 30m
# 1  2024-08-05       09:30 PM     06:45 AM         13h 15m
# 2  2024-08-10       01:45 PM     05:30 AM          8h 45m
#
#    Number_of_Stops_Num  Price_Normalized  PriceZScore  FlightYear  \
# 0                    0          0.000000    -1.073578        2024
# 1                    1          0.384615    -0.079524        2024
# 2                    2          1.000000     1.510961        2024
#
#    FlightMonth  FlightDay
# 0            8          1
# 1            8          5
# 2            8         10

# %%
# dropping Number of stops column
flight_df.drop(columns=['Number_of_Stops'], inplace = True)
flight_df
# Out:
#            Airline Source_City Destination_City  Ticket_Price Flight_Date  \
# 0       fly jinnah   abu dhabi   united kingdom           550  2024-08-01
# 1         emirates       dubai    saudia arabia           800  2024-08-05
# 2          airblue   islamabad             oman          1200  2024-08-10
# 3  turkish airline    istanbul          germany           650  2024-08-15
# 4         emirates     karachi            dubai           900  2024-08-20
#
#   Departure_Time Arrival_Time Flight_Duration  Number_of_Stops_Num  \
# 0       08:00 AM     10:00 PM          7h 30m                    0
# 1       09:30 PM     06:45 AM         13h 15m                    1
# 2       01:45 PM     05:30 AM          8h 45m                    2
# 3       10:00 AM     02:00 PM          15h 0m                    0
# 4       11:15 PM     03:15 AM         14h 30m                    1
#
#    Price_Normalized  PriceZScore  FlightYear  FlightMonth  FlightDay
# ...

# %% [markdown]
# ### Working with Categorical Data:

# %% [markdown]
# The categorical columns in our dataframe are:
# - Airline
# - Source city
# - Destination city

# %%
# Convert a categorical column to numerical using one-hot encoding
df = pd.get_dummies(flight_df, columns=['Airline'], prefix='')
df.head()
# Out:
#   Source_City Destination_City  Ticket_Price Flight_Date Departure_Time  \
# 0   abu dhabi   united kingdom           550  2024-08-01       08:00 AM
# 1       dubai    saudia arabia           800  2024-08-05       09:30 PM
# 2   islamabad             oman          1200  2024-08-10       01:45 PM
# 3    istanbul          germany           650  2024-08-15       10:00 AM
# 4     karachi            dubai           900  2024-08-20       11:15 PM
#
#   Arrival_Time Flight_Duration  Number_of_Stops_Num  Price_Normalized  \
# 0     10:00 PM          7h 30m                    0          0.000000
# 1     06:45 AM         13h 15m                    1          0.384615
# 2     05:30 AM          8h 45m                    2          1.000000
# 3     02:00 PM          15h 0m                    0          0.153846
# 4     03:15 AM         14h 30m                    1          0.538462
#
#    PriceZScore  FlightYear  FlightMonth  FlightDay  _airblue  _emirates  \
# ...

# %% [markdown]
# ##### Adding new column in the DataFrame:

# %%
# declare a list that is converted into column

flight_no = [303, 470, 770, 740, 644]

flight_df['Flight_No'] = flight_no
flight_df
# Out:
#            Airline Source_City Destination_City Number_of_Stops  Ticket_Price  \
# 0       Fly Jinnah   Abu Dhabi   United Kingdom        Non-stop           550
# 1        Fly Dubai       Dubai    Saudia Arabia          1 Stop           800
# 2          AirBlue   Islamabad             Oman         2 Stops          1200
# 3  Turkish Airline    Istanbul          Germany        Non-stop           650
# 4        Fly Dubai     Karachi            Dubai          1 Stop           900
#
#   Flight_Date Departure_Time Arrival_Time Flight_Duration  Flight_No
# 0  2024-08-01       08:00 AM     10:00 PM          7h 30m        303
# 1  2024-08-05       09:30 PM     06:45 AM         13h 15m        470
# 2  2024-08-10       01:45 PM     05:30 AM          8h 45m        770
# 3  2024-08-15       10:00 AM     02:00 PM          15h 0m        740
# 4  2024-08-20       11:15 PM     03:15 AM         14h 30m        644

# %%
# shift column to first position
first_column = flight_df.pop('Flight_No')

# insert column using insert(position, column_name, first_column) function 
flight_df.insert(0, 'Flight_No', first_column)
flight_df
# Out:
#    Flight_No          Airline Source_City Destination_City Number_of_Stops  \
# 0        303       Fly Jinnah   Abu Dhabi   United Kingdom        Non-stop
# 1        470        Fly Dubai       Dubai    Saudia Arabia          1 Stop
# 2        770          AirBlue   Islamabad             Oman         2 Stops
# 3        740  Turkish Airline    Istanbul          Germany        Non-stop
# 4        644        Fly Dubai     Karachi            Dubai          1 Stop
#
#    Ticket_Price Flight_Date Departure_Time Arrival_Time Flight_Duration
# 0           550  2024-08-01       08:00 AM     10:00 PM          7h 30m
# 1           800  2024-08-05       09:30 PM     06:45 AM         13h 15m
# 2          1200  2024-08-10       01:45 PM     05:30 AM          8h 45m
# 3           650  2024-08-15       10:00 AM     02:00 PM          15h 0m
# 4           900  2024-08-20       11:15 PM     03:15 AM         14h 30m

# %% [markdown]
# ### DataFrame Concatenation:

# %% [markdown]
# Concatenation in Pandas is used to combine two or more DataFrames along a particular axis (either rows or columns). This operation is commonly used to merge datasets with similar or complementary data.

# %% [markdown]
# ##### Merge Two DataFrames:
#
#
# You can use pd.merge() function.

# %%
# Merge two DataFrames based on a common column
df_additional = pd.DataFrame({
    'Flight_No': [303, 470, 770, 740, 644],
    'Flight_Classes': ['Economy Class', 'Business Class', 'First Class', 'Economy Class', 'Business Class']
})
df_merged = pd.merge(flight_df, df_additional, on='Flight_No')
print("\nMerged DataFrame:")
df_merged
# Out:
# Merged DataFrame:
#    Flight_No          Airline Source_City Destination_City  Ticket_Price  \
# 0        303       fly jinnah   abu dhabi   united kingdom           550
# 1        470         emirates       dubai    saudia arabia           800
# 2        770          airblue   islamabad             oman          1200
# 3        740  turkish airline    istanbul          germany           650
# 4        644         emirates     karachi            dubai           900
#
#   Flight_Date Departure_Time Arrival_Time Flight_Duration  \
# 0  2024-08-01       08:00 AM     10:00 PM          7h 30m
# 1  2024-08-05       09:30 PM     06:45 AM         13h 15m
# 2  2024-08-10       01:45 PM     05:30 AM          8h 45m
# 3  2024-08-15       10:00 AM     02:00 PM          15h 0m
# 4  2024-08-20       11:15 PM     03:15 AM         14h 30m
#
#    Number_of_Stops_Num  Price_Normalized  PriceZScore  FlightYear  \
# 0                    0          0.000000    -1.073578        2024
# ...

# %% [markdown]
# ##### Vertical Concatenation (Appending Rows):

# %% [markdown]
# To concatenate DataFrames vertically (i.e., to add rows), you can use the pd.concat() function with axis=0.

# %%
# concatenate two DataFrames vertically
df_additional_rows = pd.DataFrame({
    'Flight_No': [747, 700],
    'Airline': ['saudi airline', 'emirates'],
    'Source_City': ['karachi', 'london'],
    'Destination_City': ['baku', 'qatar'],
    'Ticket_Price': [600, 450],
    'Flight_Date': ['2023-07-10', '2023-07-15'],
    'Departure_Time': ['10:30 AM', '5:30 AM'],
    'Arrival_Time': ['12:00 PM', '10:00 AM']
})
df_concat_vert = pd.concat([flight_df, df_additional_rows], ignore_index=True)
print("\nDataFrame after vertical concatenation:")
df_concat_vert
# Out:
# DataFrame after vertical concatenation:
#    Flight_No          Airline Source_City Destination_City  Ticket_Price  \
# 0        303       fly jinnah   abu dhabi   united kingdom           550
# 1        470         emirates       dubai    saudia arabia           800
# 2        770          airblue   islamabad             oman          1200
# 3        740  turkish airline    istanbul          germany           650
# 4        644         emirates     karachi            dubai           900
# 5        747    saudi airline     karachi             baku           600
# 6        700         emirates      london            qatar           450
#
#   Flight_Date Departure_Time Arrival_Time Flight_Duration  \
# 0  2024-08-01       08:00 AM     10:00 PM          7h 30m
# 1  2024-08-05       09:30 PM     06:45 AM         13h 15m
# 2  2024-08-10       01:45 PM     05:30 AM          8h 45m
# 3  2024-08-15       10:00 AM     02:00 PM          15h 0m
# ...

# %% [markdown]
# ##### Horizontal Concatenation (Adding Columns):

# %% [markdown]
# To concatenate DataFrames horizontally (i.e., to add columns), use the pd.concat() function with axis=1.

# %%
# Concatenate two DataFrames horizontally
df_add_cols = pd.DataFrame({
    'Flight_No': [303, 470, 770, 740, 644, 747],
    'Meal_Served': ['Yes', 'Yes', 'No', 'Yes', 'No', 'Yes']
})
df_concat_horiz = pd.concat([flight_df, df_add_cols], axis=1)
print("\nDataFrame after horizontal concatenation:")
df_concat_horiz
# Out:
# DataFrame after horizontal concatenation:
#    Flight_No          Airline Source_City Destination_City  Ticket_Price  \
# 0      303.0       fly jinnah   abu dhabi   united kingdom         550.0
# 1      470.0         emirates       dubai    saudia arabia         800.0
# 2      770.0          airblue   islamabad             oman        1200.0
# 3      740.0  turkish airline    istanbul          germany         650.0
# 4      644.0         emirates     karachi            dubai         900.0
# 5        NaN              NaN         NaN              NaN           NaN
#
#   Flight_Date Departure_Time Arrival_Time Flight_Duration  \
# 0  2024-08-01       08:00 AM     10:00 PM          7h 30m
# 1  2024-08-05       09:30 PM     06:45 AM         13h 15m
# 2  2024-08-10       01:45 PM     05:30 AM          8h 45m
# 3  2024-08-15       10:00 AM     02:00 PM          15h 0m
# 4  2024-08-20       11:15 PM     03:15 AM         14h 30m
# 5         NaN            NaN          NaN             NaN
#
# ...

# %% [markdown]
# ### Polynomial Fitting:

# %%
# column for polynomial feature generation (numerical columns only)
num_col = ['Ticket_Price']

# create polynomial features (degree 2 as an example)
for col in num_col:
    flight_df[f'{col}^2'] = flight_df[col] ** 2  # square of the column
    flight_df[f'{col}^3'] = flight_df[col] ** 3  # cube of the column

# optionally, add interaction terms between the columns
# In this example it won't add new column as we have only one numerical column
'''for i in range(len(num_col)):
    for j in range(i+1, len(num_col)):
        col1 = num_col[i]
        col2 = num_col[j]
        df[f'{col1}*{col2}'] = df[col1] * df[col2]'''

flight_df
# Out:
#    Flight_No          Airline Source_City Destination_City Number_of_Stops  \
# 0        303       Fly Jinnah   Abu Dhabi   United Kingdom        Non-stop
# 1        470        Fly Dubai       Dubai    Saudia Arabia          1 Stop
# 2        770          AirBlue   Islamabad             Oman         2 Stops
# 3        740  Turkish Airline    Istanbul          Germany        Non-stop
# 4        644        Fly Dubai     Karachi            Dubai          1 Stop
#
#    Ticket_Price Flight_Date Departure_Time Arrival_Time Flight_Duration  \
# 0           550  2024-08-01       08:00 AM     10:00 PM          7h 30m
# 1           800  2024-08-05       09:30 PM     06:45 AM         13h 15m
# 2          1200  2024-08-10       01:45 PM     05:30 AM          8h 45m
# 3           650  2024-08-15       10:00 AM     02:00 PM          15h 0m
# 4           900  2024-08-20       11:15 PM     03:15 AM         14h 30m
#
#    Ticket_Price^2  Ticket_Price^3
# 0          302500       166375000
# ...
